# %% [markdown]
# <a href="https://colab.research.google.com/github/nalgo-intern/Nakamura-test/blob/feature/something.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def A():
  print("A")
  B()
def B():
  print("B")
  A()

A()
# Out:
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# A
# B
# ...
